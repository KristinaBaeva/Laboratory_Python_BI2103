# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Тема-3.-Функции" data-toc-modified-id="Тема-3.-Функции-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Тема 3. Функции</a></span></li><li><span><a href="#Задания" data-toc-modified-id="Задания-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Задания</a></span></li></ul></div>

# %% [markdown]
# # Тема 3. Функции

# %% [markdown]
# # Задания
#
# Выполните задания

# %% [markdown]
# 1. Имеется список из 20 случайных чисел от 0 до 100. Напишите функцию, которая разбивает этот список на $n$ списков по $k$ элементов и включает все эти списки в новый список. Используйте $k$ в качестве параметра функции.
#
# 2. Напишите функцию, вычисляющую факториал числа, передаваемого в качестве параметра.
#
# 3. Написать функцию умножения, принимающую от одного до трех параметров. Функцию вызвать с приведенными ниже аргументами. Для случая a4 выбрать 3 первых и 3 последних значения.
# ```
# a1 = (15, 10 ,5)
# a2 = (3, 1)
# a3 = [2, 35, 55]
# a4 = (5, 10 ,15, 20)
# ```
#
# 4. Напишите функцию, которая для заданного радиуса r вычисляет площадь круга и длину окружности. Функция возвращает кортеж из 2 значений.
#
# 5. Реализовать функции для выполнения четырех арифметических операций, преобразующих целые числа в целое число. Создать словарь с функциями исоответствующими им симв олами операций. Для двух заранее заданных целых чисел (например, 25 и 4) выполнить выбранную пользователем арифметическую операцию.
#
# 6. Написать калькулятор для строковых выражений вида '<число> <операция> <число>', где <число> - целое число, например 113, <арифметическая операция> - одна из операций `+,-,*,//,%,^`. Пример: `calc('13 - 5') -> 8`
#
# 7. Написать функцию, которая преобразует целое число (от 0 до 999) из текстового представления на русском языке в число типа int. Пример: `to_int('тридцать три') -> 33`
#
# 8. Написать функцию, которая преобразует целое число (от 0 до 999) из текстового представления на русском языке в число типа int. И сообщает об ошибках (выводит на экран описание типа ошибки и возвращает число -1). Пример: to_int('тридцать три') -> 33 Пример: to_int("сто сорок тридцать два сто") -> -1 Вывод: тридцать - некорректное расположение в числе.

# %% [markdown]
# 1) Имеется список из 20 случайных чисел от 0 до 100. Напишите функцию, которая разбивает этот список на 𝑛 списков по 𝑘 элементов и включает все эти списки в новый список. Используйте 𝑘 в качестве параметра функции.

# %% [markdown]
# Алгоритм выполнения:
#
# 1) Подключаем модуль random, из которого импортируем функцию (метод) randint(). Python возвращает случайное целочисленное значение между двумя нижними и верхними пределами, предоставленными, как два параметра;
#
# 2) Создаем пустой список random_list, который в последствии будем заполнять;
#
# 3) Далее нам понадобится цикл for, в котором мы будем заполнять список рандомными значениями. Метод range() позволяет генерировать ряд чисел в рамках заданного диапазона. В данном примере нам нужно 20 чисел.
#
# 4) Используем внутри тела цикла метод append() добавляет в конец списка элемент, переданный ему в качестве аргумента. В данном примере нам нужны числа от 0 до 100.
#
# 5) Создадим функцию chunk_list (chunk - порезанный на кусочки). В качестве аргументов функции мы передаем наш список random_list и заявленные в задании k - количество элементов, которые будут делить список random_list на части.
#
# 6) В теле функции будет выполняться цикл for, в котором мы перебираем наш список random_list, используя функцию range(). Мы начинаем отбор со значения 0, проходим по всей длине нашего random_list с помощью функции len(), разбивая по заданному значению - k_elems.
#
# 7) Когда мы тестируем функцию, объявляем переменную k_elems, которой мы установили любое значение, чтобы указать, что мы хотим разделить наш список на фрагменты размером k.
#
# 8) Затем мы заносим в пустой список chunked_list (который мы объявили выше) с помощью уже известной мне функции append() элементы списка с помощью записи "i:i + k_elems", которая означает, что будет генерироваться n-список от i до i + следующий n-список
#
# 9) Объявляем переменную result, в которую запишем результат работы функции chunk_list

# %%
from random import randint #используем метод randint()

######################################################

def chunk_list(random_list, k_elems): #создаём функцию chunk_list
    chunked_list = []
    for i in range(0, len(random_list), k_elems):
        chunked_list.append(random_list[i:i + k_elems])
    return chunked_list

######################################################

random_list = [] #создаем пустой список 
for i in range(20): #далее нам понадобится цикл for, в котором мы будем заполнять список рандомными значениями
    random_list.append(randint(0, 100))
#print(random_list)

k_elems = 6
result = chunk_list(random_list, k_elems)
print(result)
# Out:
# [[52, 76, 54, 18, 72, 23], [49, 100, 7, 81, 92, 74], [60, 26, 41, 11, 21, 1], [100, 38]]

# %% [markdown]
# 2) Напишите функцию, вычисляющую факториал числа, передаваемого в качестве параметра.
#
# Алгоритм выполнения:
#
# 1) Факториал — это произведение всех натуральных чисел от 1 до данного числа. Например, факториал числа 5 будет равен 1 × 2 × 3 × 4 × 5 = 120
#
# 2) Выполним данное задание с помощью рекурсии. Рекурсия - это функция, которая вызывает саму себя.
#
# 3) Объявляем функцию factorial и передаём в неё аругмент number (это то самое число, факториал которого мы пытаемся найти)
#
# 3) Рекурсия закачнивает свою работу, как только number становится равный единице, потому что факториал единицы - это 1, мы и пишем в первом if: если заданное число равно 1 - то мы вернём значение number. Функция прекращается, и рекурсия останавливается.
#
# 4) Если же наше число не равно 1, то мы умножаем заданное число number на функцию factorial (number - 1). (number - 1) - это значение числа, уменьшающееся на 1, как в представленном выше примере с факториалом пяти. Сначала number (5) умножается на функцию factorial (5 - 1). И так функция будет работать пока число (number) в скобках не станет равно 1, и рекурсия не остановится.
#
# 5) Задаем любое желаемое число и выводим результат.

# %%
def factorial(number):
    if number == 1:
        return number
    else:
        return number * factorial(number - 1)

task_number = int(input('Введите число: '))
print(factorial(task_number))
# Out:
# Введите число: 3
# 6

# %% [markdown]
# 3) Написать функцию умножения, принимающую от одного до трех параметров. Функцию вызвать с приведенными ниже аргументами. Для случая a4 выбрать 3 первых и 3 последних значения.
#
# a1 = (15, 10 ,5)
#
# a2 = (3, 1)
#
# a3 = [2, 35, 55]
#
# a4 = (5, 10 ,15, 20)
#
# Алгоритм выполнения:
# 1) Определение функции Func с аргументами *args* что позволяет передавать произвольное количество аргументов.
# 2) Проверка, если длина args равна 0 (т.е., если ни одного аргумента не передано), то функция возвращает 0.
# 3) Инициализируем переменную key_arg (ключевой аргумент, который мы будем использовать для умножения) равной 1.
# 4) Затем начинается цикл for, который перебирает все переданные аргументы.
# 5) В каждой итерации аргумент (arg) умножается на текущее значение key_arg, чтобы накопить их произведение.
# 5) В конце цикла key_arg содержит результат умножения всех аргументов.
# 6) Функция возвращает значение key_arg.
#
# *Func(5) вернет 5 (поскольку единственный переданный аргумент умножается сам на себя).

# %%
def Func(*args):

    if len(args) == 0:  
        return(0)       
                    
    key_arg = 1
    for arg in args:
        key_arg *= arg
    return(key_arg)


print(Func("В случае если мы ничего не передаём: "))
print("a1:", Func(15, 10, 5))
print("a2:", Func(3, 1))
print("a3:", Func(2, 35, 55))
print("a4:", Func(5, 10, 15, 10, 15, 20))
print("a5:", Func(5))
# Out:
# В случае если мы ничего не передаём:
# a1: 750
# a2: 3
# a3: 3850
# a4: 2250000
# a5: 5

# %% [markdown]
# 4) Напишите функцию, которая для заданного радиуса r вычисляет площадь круга и длину окружности. Функция возвращает кортеж из 2 значений.
#
# Алгоритм выполнения:
# 1) Определение значения Pi как 3.14.
# 2) Определение функции radius_characteristics с аргументом Rad.
# 3) Внутри функции вычисление площади круга S и длины окружности C на основе переданного радиуса Rad:
# 4) Площадь круга S рассчитывается как Pi * Rad**2.
# 5) Длина окружности C рассчитывается как 2 * Pi * Rad.
# 6) Функция возвращает список [S, round(C, 1)], где S - площадь круга, а C - длина окружности, округленная до одной десятой.

# %%
Pi = 3.14

def radius_characteristics (Rad):
    S = Pi * Rad**2
    C = 2*Pi*Rad
    return [S, round(C, 1)]
    
result = radius_characteristics(5)
print (result)
# Out:
# [78.5, 31.4]

# %% [markdown]
# 5) Реализовать функции для выполнения четырех арифметических операций, преобразующих целые числа в целое число.
# Создать словарь с функциями и соответствующими им символами операций.
# Для двух заранее заданных целых чисел (например, 25 и 4) выполнить выбранную пользователем арифметическую операцию.
#
# Алгоритм выполнения:
# 1) Определение четырех функций: Addition, Subtraction, Multiplication и Division, каждая из которых принимает два аргумента a и b и выполняет операции сложения, вычитания, умножения и деления соответственно. Каждая из этих функций возвращает результат операции, преобразованный в целое число (с использованием int).
#
# 2) Запрос ввода двух чисел a и b с помощью input(). Оба введенных значения преобразуются в числа с плавающей запятой (float).
#
# 3) Запрос ввода оператора (operator) с помощью input().
#
# 4) Создание словаря dictionary, в котором каждому оператору ('+', '-', '*', '/') сопоставляется соответствующая функция из определенных ранее (Addition, Subtraction, Multiplication, Division).
#
# 5) Вызов выбранной функции из словаря dictionary[operator](a, b) с аргументами a и b. В зависимости от введенного оператора, будет выполнена соответствующая операция с числами a и b.

# %%
def Addition(a, b):
    return int(a + b)

def Subtraction (a, b):
    return int(a - b)

def Multiplication (a, b):
    return int(a * b)

def Division (a, b):
    return int(a // b)

a, b, operator = float(input()), float(input()), input() 

dictionary = {'+': Addition,
              '-': Subtraction,
              '*': Multiplication,
              '/': Division}

print(dictionary[operator](a, b))
# Out:
# 25
# 4
# *
# 100

# %% [markdown]
# 6) Написать калькулятор для строковых выражений вида '<число> <операция> <число>', где <число> - целое число, например 113, <арифметическая операция> - одна из операций +,-,*,//,%,^. Пример: calc('13 - 5') -> 8
#
# Алгоритм выполнения:
#
# 1) Определение функции WordCalculator(expression). Функция принимает строку expression, которая содержит математическое выражение в формате '<число> <операция> <число>'.
#
# 2) Разделение строки на элементы. Строка expression разделяется на элементы (число1, оператор, число2) с помощью функции split().
#
# 3) Проверка формата ввода. Проверяется, что количество элементов равно 3 (число1, оператор, число2). Если не равно, возвращается сообщение "Некорректный формат ввода".
#
# 4) Проверка числовых значений. Проверяется, что число1 и число2 состоят из цифр (являются числами) с  помощью метода isdigit(). Если не являются, возвращается сообщение "Введите целые числа".
#
# 5) Преобразование строк в числа. Строковые представления числа1 и число2 преобразуются в целочисленные значения.
#
# 6) Выполнение операции в зависимости от оператора:
#
# 7) В зависимости от оператора (+, -, *, /), выполняется соответствующая математическая операция над числами.
#
# Для деления (/) проверяется, что делитель (число2) не равен нулю.
# Для целочисленного деления (//), возвращается целочисленное значение.
#
# **Метод split () разбивает объект String на массив строк путём разделения строки указанной подстрокой.

# %%
def WordCalculator(expression):
    
    elements = expression.split()
    
    if len(elements) != 3:
        return "Некорректный формат ввода"
    
    num1, op, num2 = elements
    
    if not (num1.isdigit() and num2.isdigit()):
        return "Введите целые числа"
    
    num1, num2 = int(num1), int(num2)

    if op == '+':
        result = num1 + num2
    elif op == '-':
        result = num1 - num2
    elif op == '*':
        result = num1 * num2
    elif op == '/':
        if num2 == 0:
            return "Деление на ноль недопустимо"
        result = num1 // num2
    else:
        return "Неподдерживаемая операция"
    
    return result

expression = input("Введите строковое выражение вида '<число> <операция> <число>': ")
print("Результат:", WordCalculator(expression))
# Out:
# Введите строковое выражение вида '<число> <операция> <число>': 5 + 9
# Результат: 14

# %% [markdown]
# 7) Написать функцию, которая преобразует целое число (от 0 до 999) из текстового представления на русском языке в число типа int. Пример: to_int('тридцать три') -> 33
#
# **1) Создание словаря с числительными и числами.
#
# Создаем словарь dictionary, который содержит написанные словами числа.
#
# **2) Подготовка текста для обработки:
#
# Входное текстовое представление числа (переменная) text_number разбивается на отдельные слова с помощью функции .split(). Сплит работает по принципу: когда встречается первый пробел, метод разбивает строку.
# Все слова приводятся к нижнему регистру с помощью .lower(), чтобы обеспечить независимость от регистра при сопоставлении слов с числами.
#
# **3) Инициализация переменных:
#
# Создаём переменную current_number, которую инициализируем 0.
# current_number будет использоваться для хранения текущей суммы чисел по мере прохождения по словам.
#
# **4) Итерация по словам и суммирование значений:
#
# Следующим шагом происходит перебор по каждому слову, которое было разбито на этапе 2.
# Для каждого слова выполняется проверка: присутствует ли оно в словаре dictionary. Если слово найдено в словаре, его числовое значение прибавляется к current_number.
# Если слово не найдено в словаре (слово не является числительным), функция сразу возвращает строку "Неверное слово в числе". Это предотвращает продолжение выполнения функции, если обнаружено неверное слово.
#
# **5)Возвращение результата:
#
# По завершении итерации по словам возвращается значение current_number, которое является суммой чисел, соответствующих текстовому представлению.

# %%
def to_int(text_number):
    # 1
    dictionary = {
        'ноль': 0, 'один': 1, 'два': 2, 'три': 3, 'четыре': 4,
        'пять': 5, 'шесть': 6, 'семь': 7, 'восемь': 8, 'девять': 9,
        'десять': 10, 'одиннадцать': 11, 'двенадцать': 12, 'тринадцать': 13, 'четырнадцать': 14,
        'пятнадцать': 15, 'шестнадцать': 16, 'семнадцать': 17, 'восемнадцать': 18, 'девятнадцать': 19,
        'двадцать': 20, 'тридцать': 30, 'сорок': 40, 'пятьдесят': 50, 'шестьдесят': 60,
        'семьдесят': 70, 'восемьдесят': 80, 'девяносто': 90,
        'сто': 100, 'двести': 200, 'триста': 300, 'четыреста': 400, 'пятьсот': 500,
        'шестьсот': 600, 'семьсот': 700, 'восемьсот': 800, 'девятьсот': 900
    }

    # 2
    words = text_number.lower().split()

    #3
    current_number = 0

    # Проходим по словам и суммируем значения
    for word in words:
        if word in dictionary:
            current_number += dictionary[word]
        else:
            # Обработка случая, когда слово не найдено в словаре
            return "Неверное слово в числе"

    return current_number

#text_number = 'пятьсот двадцать три'
text_number = input()
result = to_int(text_number)

print("Результат:", result)
# Out:
# пятьсот двадцать три
# Результат: 523

# %% [markdown]
# 9) Написать функцию, которая преобразует целое число (от 0 до 999) из текстового представления на русском языке в число типа int. И сообщает об ошибках (выводит на экран описание типа ошибки и возвращает число -1). Пример: to_int('тридцать три') -> 33 Пример: to_int("сто сорок тридцать два сто") -> -1 Вывод: тридцать - некорректное расположение в числе.
#
# Алгоритм выполнения:
# 1) Создаем словарь numbers_dict, который содержит написанные словами числа. Например, 1 соответствует 'один'.
#
# 2) Функция int_to_text(number) принимает один аргумент - number, который представляет собой целое число, которое нужно преобразовать.
#
# 3) Если переданное число number существует в словаре numbers_dict, то функция возвращает соответствующее текстовое представление для этого числа. Проверяется с помощью условной операции if.
#
# 4) Если число number находится в диапазоне от 1 до 999 (включительно), то выполняется следующее:
#
#     hundreds вычисляет количество сотен в числе (например, для числа 523 это будет 500).
#
#     remainder вычисляет остаток, оставшийся после вычета сотен (для числа 523 это будет 23).
#
#     Если remainder равен 0, то функция возвращает текстовое представление для сотен (например, 'пятьсот').
#
#     Если remainder меньше 20, то функция возвращает комбинацию текстовых представлений для сотен и остатка (например, 'пятьсот двадцать три').
#
#     Если remainder больше 20, то функция далее разбивает remainder на десятки и единицы:
#         tens - количество десятков в остатке (например, для 23 это будет 20).
#         ones - количество единиц в остатке (например, для 23 это будет 3).
#     Если ones равно 0, то функция возвращает текстовое представление для сотен и десятков (например, 'пятьсот двадцать').
#
# Если число number находится вне диапазона от 1 до 999, функция вернет сообщение "Число вне диапазона (1-999)".
#
# После вызова функции пользователь вводит число (number) с клавиатуры, и функция int_to_text вызывается с этим числом. Результат преобразования сохраняется в переменной result.

# %%
def int_to_text(number):

    numbers_dict = {
        0: 'ноль', 1: 'один', 2: 'два', 3: 'три', 4: 'четыре',
        5: 'пять', 6: 'шесть', 7: 'семь', 8: 'восемь', 9: 'девять',
        10: 'десять', 11: 'одиннадцать', 12: 'двенадцать', 13: 'тринадцать', 14: 'четырнадцать',
        15: 'пятнадцать', 16: 'шестнадцать', 17: 'семнадцать', 18: 'восемнадцать', 19: 'девятнадцать',
        20: 'двадцать', 30: 'тридцать', 40: 'сорок', 50: 'пятьдесят', 60: 'шестьдесят',
        70: 'семьдесят', 80: 'восемьдесят', 90: 'девяносто',
        100: 'сто', 200: 'двести', 300: 'триста', 400: 'четыреста', 500: 'пятьсот',
        600: 'шестьсот', 700: 'семьсот', 800: 'восемьсот', 900: 'девятьсот'
    }

    # number - передаваемый аргумент в нашу функцию
    if number in numbers_dict:
        return numbers_dict[number]
    
    elif 0 < number < 1000:
        hundreds = number // 100 * 100 #то есть если мы ввели 623, 623 // 100, то получим 6 и умножив на 100, получим сотни
        remainder = number % 100 #здесь мы находим то, что осталось от сотни, то есть 623%100 = 23
        
        if remainder == 0:
            return numbers_dict[hundreds] #Если остаток равен 0, то функция возвращает 'шестьсот').
        
        elif remainder < 20:
            return f"{numbers_dict[hundreds]} {numbers_dict[remainder]}"
        
        else:
            tens = remainder // 10 * 10 #по тому же принципу считаем десятки из остатка remainder 23//10 = 2 * 10 = 20!
            ones = remainder % 10 #получим 3, то есть последнюю цифру
            
            if ones == 0:
                return f"{numbers_dict[hundreds]} {numbers_dict[tens]}"
            else:
                return f"{numbers_dict[hundreds]} {numbers_dict[tens]} {numbers_dict[ones]}"
    else:
        return "Число вне диапазона (1-999)"

#number = 523
number = int(input())
result = int_to_text(number)
print("Результат:", result)
# Out:
# 623
# Результат: шестьсот двадцать три
